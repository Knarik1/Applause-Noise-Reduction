# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import glob
import os
import tensorflow as tf

# %reload_ext autoreload
# %autoreload 2

# %%
tf.__version__
# Out:
# '1.15.2'

# %%
# %cd /content/drive/My Drive/Applause-Noise-Reduction
os.getcwd()
# Out:
# /content/drive/My Drive/Applause-Noise-Reduction
# '/content/drive/My Drive/Applause-Noise-Reduction'

# %%
# !python main.py --mode 'train' --train_batch_size 1000 --val_batch_size 1000 --test_batch_size 1000 --learning_rate 0.001
# Out:
# WARNING:tensorflow:From main.py:72: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# ----Data Loader init----
# learning rate:  0.001
# train batch size:  1000
# WARNING:tensorflow:From /content/drive/My Drive/Applause-Noise-Reduction/models/BaseNN.py:45: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# W0407 05:57:44.867595 139624764864384 module_wrapper.py:139] From /content/drive/My Drive/Applause-Noise-Reduction/models/BaseNN.py:45: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Applause-Noise-Reduction/models/BaseNN.py:71: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...
